# %%
from datetime import datetime
from datetime import date



def validate_file(file_path, expected_entry_count):
    try:
        # Open the file for reading
        with open(file_path, 'r') as file:
            lines = file.readlines()
            #print(lines)
            #print(file)
            

            # Check if the file has at least two lines (header and tail)
            if len(lines) < 2:
                return False, "File must have at least a header and a tail."

            # Extract and validate the header (first line)
            now = datetime.now()
            header = lines[0].strip().split(',')
            today = date.today()
            d1 = today.strftime("%Y%m%d")
            print("d1 =", d1)
            print("Today's date:", today)
            today_date = now.strftime('%Y-%m-%d')
            print(header)
            print(today_date)
            if d1 != header[1]:
                return False, "Header does not contain today's date."

            # Extract and validate the tail (last line)
            tail = lines[-1].strip().split(',')
            print(tail)

            #expected_entry_count = int(tail.split(',')[1])
            print("Expected entry count",expected_entry_count)

            actual_entry_count = len(lines) - 2  # Subtract 2 for header and tail
            print("Actual entry count",actual_entry_count)

            if actual_entry_count != expected_entry_count:
                return False, f"TAIL specifies {expected_entry_count} entries, but there are {actual_entry_count} entries."

           # return True, "TAIL validation successful."
            
            #tail = lines[-1].strip()
            #tail_entry_count = int(tail.split()[-1]) -2
           
            #if tail_entry_count != expected_entry_count:
                #return False, f"Tail has {tail_entry_count} entries, but {expected_entry_count} expected."

            return True, "File validation successful."

    except FileNotFoundError:
        return False, "File not found."
    except Exception as e:
        return False, f"An error occurred: {str(e)}"

# Usage
file_path = 'C:/Users/DELL/Desktop/data.txt'
expected_entry_count = 10  # Replace with the expected entry count
validation_result, validation_message = validate_file(file_path, expected_entry_count)

if validation_result:
    print("File is valid.")
else:
    print("File validation failed:", validation_message)
# Out:
# <_io.TextIOWrapper name='C:/Users/DELL/Desktop/data.txt' mode='r' encoding='cp1252'>
# d1 = 20231025
# Today's date: 2023-10-25
# ['HEAD', '20231025']
# 2023-10-25
# ['TAIL', '12']
# Expected entry count 10
# Actual entry count 10
# File is valid.

# %%
import datetime

def validate_file(file_path, expected_entry_count):
    try:
        # Open the file for reading
        with open(file_path, 'r') as file:
            lines = file.readlines()

            # Check if the file has at least two lines (header and tail)
            if len(lines) < 2:
                return False, "File must have at least a header and a tail."

            # Extract and validate the header (first line)
            header = lines[0].strip()
            today_date = datetime.datetime.now().strftime('%Y-%m-%d')
            print(today_date)
           # if today_date not in header:
               # return False, "Header does not contain today's date."

            # Extract and validate the tail (last line)
            tail = lines[-1].strip().split(',')
            print(tail)
            print(tail_entry_count)
            if tail_entry_count != expected_entry_count:
                return False, f"Tail has {tail_entry_count} entries, but {expected_entry_count} expected."

            return True, "File validation successful."

    except FileNotFoundError:
        return False, "File not found."
    except Exception as e:
        return False, f"An error occurred: {str(e)}"

# Usage
file_path = 'C:/Users/DELL/Desktop/data.txt'
expected_entry_count = 12  # Replace with the expected entry count
validation_result, validation_message = validate_file(file_path, expected_entry_count)

if validation_result:
    print("File is valid.")
else:
    print("File validation failed:", validation_message)
# Out:
# 2023-10-22
# ['']
# File validation failed: An error occurred: name 'tail_entry_count' is not defined

# %%
import datetime

def validate_file(file_path):
    try:
        # Open the file for reading
        with open(file_path, 'r') as file:
            lines = file.readlines()

            # Check if the file has at least two lines (header and tail)
            if len(lines) < 2:
                return False, "File must have at least a header and a tail."

            # Extract and validate the header (first line)
            header = lines[0].strip()
            today_date = datetime.datetime.now().strftime('%d/%m/%Y')
            if today_date not in header:
                return False, "Header does not contain today's date."

            # Extract and validate the tail (last line)
            tail = lines[-1].strip()
            tail_entry_count = int(tail.split(',')[-1])
            if tail_entry_count != len(lines) - 2:  # Subtract 2 for header and tail
                return False, f"Tail has {tail_entry_count} entries, but {len(lines) - 2} expected."

            return True, "File validation successful."

    except FileNotFoundError:
        return False, "File not found."
    except Exception as e:
        return False, f"An error occurred: {str(e)}"

# Usage
file_path = 'C:/Users/DELL/Desktop/data.txt'  # Replace with the actual file path
validation_result, validation_message = validate_file(file_path)

if validation_result:
    print("File is valid.")
else:
    print("File validation failed:", validation_message)
# Out:
# File validation failed: An error occurred: invalid literal for int() with base 10: ''

# %%
import datetime

def validate_file(file_path):
    try:
        # Open the file for reading
        with open(file_path, 'r') as file:
            lines = file.readlines()

            # Check if the file has at least two lines (header and tail)
            if len(lines) < 2:
                return False, "File must have at least a header and a tail."

            # Extract and validate the header (first line)
            header = lines[0].strip()
            today_date = datetime.datetime.now().strftime('%d/%m/%Y')
            if today_date not in header:
                return False, "Header does not contain today's date."

            # Extract and validate the tail (last line)
            tail = lines[-1].strip()
            tail_entry_count = int(tail.split(',')[-1])
            if tail_entry_count != len(lines) - 2:  # Subtract 2 for header and tail
                return False, f"Tail has {tail_entry_count} entries, but {len(lines) - 2} expected."

            return True, "File validation successful."

    except FileNotFoundError:
        return False, "File not found."
    except Exception as e:
        return False, f"An error occurred: {str(e)}"

# Usage
file_path = 'C:/Users/DELL/Desktop/data.txt'  # Replace with the actual file path
validation_result, validation_message = validate_file(file_path)

if validation_result:
    print("File is valid.")
else:
    print("File validation failed:", validation_message)
# Out:
# File validation failed: An error occurred: invalid literal for int() with base 10: ''

# %%
import datetime

def validate_file(file_path):
    try:
        # Open the file for reading
        with open(file_path, 'r') as file:
            lines = file.readlines()

            # Check if the file has at least two lines (header and tail)
            if len(lines) < 2:
                return False, "File must have at least a header and a tail."

            # Extract and validate the header (first line)
            header = lines[0].strip()
            today_date = datetime.datetime.now().strftime('%Y%m%d')
            print(today_date)
            if today_date not in header:
                return False, "Header does not contain today's date."

            # Extract and validate the tail (last line)
            tail = lines[-1].strip()
            tail_entry_count = int(tail.split(',')[-1])
            if tail_entry_count != len(lines) - 2:  # Subtract 2 for header and tail
                return False, f"Tail has {tail_entry_count:12} entries, but {len(lines) - 2} expected."

            return True, "File validation successful."

    except FileNotFoundError:
        return False, "File not found."
    except Exception as e:
        return False, f"An error occurred: {str(e)}"

# Usage
file_path = 'C:/Users/DELL/Desktop/data.txt'  # Replace with the actual file path
validation_result, validation_message = validate_file(file_path)

if validation_result:
    print("File is valid.")
else:
    print("File validation failed:", validation_message)
# Out:
# 20231022
# File validation failed: An error occurred: invalid literal for int() with base 10: ''

# %%
import datetime

def validate_file(file_path):
    try:
        # Open the file for reading
        with open(file_path, 'r') as file:
            lines = file.readlines()

            # Check if the file has at least two lines (header and tail)
            if len(lines) < 2:
                return False, "File must have at least a header and a tail."

            # Extract and validate the header (first line)
            header = lines[0].strip().split(',')
            today_date = datetime.datetime.now().strftime('%Y%m%d')
            #checking by printing today's date
            print(today_date)
            #if header[1] != today_date:
                #return False, "Header is missing or does not contain today's date."

            # Extract and validate the tail (last line)
            tail = lines[-1].strip().split(',')
            print(tail)
            #if len(tail) != 2 or tail[0] != 'TAIL':
               # return False, "Tail is missing or incorrectly formatted."
            tail_entry_count = int(tail[1])
            print(tail_entry_count)
            if tail_entry_count != len(lines) - 2:  # Subtract 2 for header and tail
                return False, f"Tail indicates {tail_entry_count} entries, but there are {len(lines) - 2} entries."

            return True, "File validation successful."

    except FileNotFoundError:
        return False, "File not found."
    except Exception as e:
        return False, f"An error occurred: {str(e)}"

# Usage
file_path = 'C:/Users/DELL/Desktop/data.txt'  # Replace with the actual file path
validation_result, validation_message = validate_file(file_path)

if validation_result:
    print("File is valid.")
else:
    print("File validation failed:", validation_message)
# Out:
# 20231022
# ['']
# File validation failed: An error occurred: list index out of range

# %%
def validate_tail(file_path):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()

            # Check if the file has at least two lines (header and tail)
            if len(lines) < 2:
                return False, "File must have at least a header and a tail."

            # Extract and validate the tail (last line)
            tail = lines[-1].strip().split(',')
            print(tail)
            #if not tail.startswith("TAIL,"):
                #return False, "TAIL section is missing or incorrectly formatted."

            #expected_entry_count = int(tail.split(',')[1])
            print(expected_entry_count)

            actual_entry_count = len(lines) - 2  # Subtract 2 for header and tail
            print(actual_entry_count)

            if actual_entry_count != expected_entry_count:
                return False, f"TAIL specifies {expected_entry_count} entries, but there are {actual_entry_count} entries."

            return True, "TAIL validation successful."

    except FileNotFoundError:
        return False, "File not found."
    except Exception as e:
        return False, f"An error occurred: {str(e)}"

# Usage
file_path = 'C:/Users/DELL/Desktop/data.txt'  # Replace with the actual file path
validation_result, validation_message = validate_tail(file_path)

if validation_result:
    print("TAIL is valid.")
else:
    print("TAIL validation failed:", validation_message)
# Out:
# ['']
# 12
# 11
# TAIL validation failed: TAIL specifies 12 entries, but there are 11 entries.
